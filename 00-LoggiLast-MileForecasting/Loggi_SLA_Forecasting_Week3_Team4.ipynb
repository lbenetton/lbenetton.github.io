# %% [markdown]
# # Loggi SLA Forecasting
#
# ## Environment setup

# %%
import pandas as pd
import datetime
import numpy as np
import os
from sqlalchemy import create_engine, text
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## SQL Connection setup

# %%
db_host = 'postgresql://team4:team4@ds4a-lbenetton-instance.c6qxfh7ops9d.us-east-2.rds.amazonaws.com/ds4a_team4'
engine=create_engine(db_host, max_overflow=20) 

def run_query(sql):
    result = engine.connect().execution_options(isolation_level="AUTOCOMMIT").execute(text(sql))
    return pd.DataFrame(result.fetchall(), columns=result.keys())

# %% [markdown]
# ## Tabla definitions and data

# %% [markdown]
# ### Table Name: task (Tasks registry of each package journey)

# %%
sql = """select * from task limit 5;"""
Task_df = run_query(sql)
Task_df.head()
# Out:
#                                  taskid                                packid  \
# 0  b4543846-c6fd-d152-887a-ab36c6ebb52a  c958f567-f977-2c85-d3d6-b45c20763ba5
# 1  6609ed35-e0dc-bc12-3671-74e768495f53  bd035331-a93a-81c8-fc2e-0e62430d2754
# 2  a49dd036-a82b-d515-1cf6-cfb726cdfa99  d9b2f01b-a328-94eb-554f-a55c657642e3
# 3  51ef4835-350a-d51e-a2e5-518374fa1560  f2221aa3-0ee2-8390-ae20-c6b46b8cb025
# 4  abb1fae4-05b4-3ab0-ce3f-d440c30890fc  f3619b33-1359-f2f2-8e57-3a315d0d39c3
#
#                             itineraryid               tasktype  \
# 0  3a782459-c460-5731-1ad9-f55bb3cf5845                Entrega
# 1  e6ac457e-1637-807f-892a-53c14de44090                Entrega
# 2  660549ae-3f41-b11f-96b5-4ac295954a69  Retirada no last-mile
# 3  e5d67a86-2ce3-ca14-6564-d3a1d379a694                Entrega
# 4  4c65010b-e0cb-b3ee-da07-7ed37275baa5  Retirada no last-mile
#
#                ackstatus         waypointrole           completed
# 0  Realizado com sucesso    Recipient Address 2019-10-30 12:32:14
# 1  Realizado com sucesso    Recipient Address 2019-10-30 12:03:36
# 2  Realizado com sucesso  Distribution Center 2019-10-30 12:04:01
# 3  Realizado com sucesso    Recipient Address 2019-10-30 12:32:40
# 4  Realizado com sucesso  Distribution Center 2019-10-30 12:42:28

# %% [markdown]
# ### Table Name: package (Package registry I)

# %%
sql = """select * from package where packid = 'c958f567-f977-2c85-d3d6-b45c20763ba5'  limit 5;"""
Task_df = run_query(sql)
Task_df.head()
# Out:
#                                  packid agreedslo  finalcity mesoregion  \
# 0  c958f567-f977-2c85-d3d6-b45c20763ba5        D1  São Paulo  São Paulo
#
#                               companyid    status        deadlinetime  \
# 0  a592c251-1dd2-bd65-9e71-616c9b46c5b6  Entregue 2019-10-30 22:00:00
#
#     firstdeliverytime  height  length  width  realweight
# 0 2019-10-30 12:32:14     5.0    29.0   22.0        0.26

# %% [markdown]
# ### Table Name: packagedenorm (Package registry II)

# %%
sql = """select * from packagedenorm where packid = 'c958f567-f977-2c85-d3d6-b45c20763ba5' limit 5;"""
Task_df = run_query(sql)
Task_df.head()
# Out:
#                                  packid agreedslo  finalcity mesoregion  \
# 0  c958f567-f977-2c85-d3d6-b45c20763ba5        D1  São Paulo  São Paulo
#
#                               companyid    status  height  length  width  \
# 0  a592c251-1dd2-bd65-9e71-616c9b46c5b6  Entregue     5.0    29.0   22.0
#
#    realweight        deadlinetime   firstdeliverytime crossdockingarrivaltime  \
# 0        0.26 2019-10-30 22:00:00 2019-10-30 12:32:14     2019-10-30 00:22:39
#
#   transferdispatchtime transferreceivaltime lastmileallocationstarttime  \
# 0  2019-10-30 09:22:39                 None         2019-10-30 11:32:28
#
#   lastmiledriverpickuptime
# 0      2019-10-30 11:50:18

# %% [markdown]
# ### Table Name: itinerary (Itinerary registry for packages)

# %%
sql = """select * from itinerary where itineraryid = '3a782459-c460-5731-1ad9-f55bb3cf5845' limit 5;"""
Task_df = run_query(sql)
Task_df.head()
# Out:
#                             itineraryid                 created  packages  \
# 0  3a782459-c460-5731-1ad9-f55bb3cf5845 2019-10-30 11:32:33.724      13.0
#
#                  accepted           checkedin      pickupcheckout       city  \
# 0 2019-10-30 11:39:19.433 2019-10-30 11:45:09 2019-10-30 11:50:18  São Paulo
#
#      status transporttype product productversion  \
# 0  finished          Moto     Pro          Prime
#
#                 distributioncenter  expectedcompletiontime
# 0  [INATIVO] São Paulo - Aclimação                  6758.0

# %%
sql = """select * from task where itineraryid = '3a782459-c460-5731-1ad9-f55bb3cf5845' order by completed DESC limit 50;"""
Task_df = run_query(sql)
Task_df.head(50)
# Out:
#                                   taskid  \
# 0   5ad3fa16-71e8-7f1a-77c7-b30b3a933ce7
# 1   ca00137e-63d1-272e-2bbb-a2403a365685
# 2   411e065e-7e8d-1bb2-6578-b2e3cf4b1d09
# 3   7c29f12d-6d70-9065-340d-603eeb89d34e
# 4   b288c790-0edd-df9a-19ab-ea6091ca0b65
# 5   9919eba2-3dc4-077e-4a09-f81e66cfef76
# 6   b4543846-c6fd-d152-887a-ab36c6ebb52a
# 7   0a4b254d-a3e8-84d5-c5a2-365657df1974
# 8   b723bb3a-ca6b-1d37-ccce-c74609bdd8ef
# 9   49240cd0-4ab5-7275-dad3-7a9545531501
# 10  4c72575f-1873-1bd0-09c7-f767d6f6058a
# 11  575dad16-e58d-2b9f-2d76-871979797702
# 12  a61f191f-94f3-683e-0017-69bd334efab0
# 13  4a75f1e1-cff5-2c5d-9f95-72e4f5a04a84
# 14  d62081a8-432f-87fd-115e-5518a17f0685
# 15  9510f99d-43da-f307-06e3-62aa41f476a3
# 16  073da22d-9fe5-500b-0090-9458a674584a
# 17  ded42541-00d9-eb96-8f76-a37b34c48e14
# 18  70f5b206-d33a-4f18-67e8-4a4f0cc51dbf
# 19  dd99da00-412d-5a3a-82e0-3cc87c5d8970
# 20  a0354196-ef08-ba73-09e8-b9f320b14fed
# 21  27cd1870-599e-ac4f-8424-e1b56240e002
# 22  f6f9bc8b-d5ce-9ee0-4f26-1acb3dc9bfe4
# 23  9a661873-0ac7-072d-6cba-e7865f127e5d
# 24  51928cb2-63fb-e569-d2ef-b46b498f64fc
Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 14  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 15  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 16  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 17  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 18  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 19  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 20  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 21  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 22  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 23  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 24  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18
# 25  Realizado com sucesso  Distribution Center 2019-10-30 11:50:18

# %% [markdown]
# ### Table Name: transfer (Transfer ID registry and location)

# %%
sql = """select * from transfer limit 5;"""
Task_df = run_query(sql)
Task_df.head()
# Out:
#                                transfer    status loadstartedtime  \
# 0  cc237aa1-4fd2-43af-aaf8-746e534c4bc2  finished            None
# 1  6a7bbdb7-df44-4165-81d4-32c1246467ec  finished            None
# 2  e1e0b311-8ae1-4d02-926c-309936ca3689  finished            None
# 3  d672286d-5a8b-47e4-8333-27cf24894b80  finished            None
# 4  44bb0ea8-13d9-4849-a79f-469bbda4694c  finished            None
#
#   transferstartedtime transferendedtime unloadendedtime  \
# 0                None              None            None
# 1                None              None            None
# 2                None              None            None
# 3                None              None            None
# 4                None              None            None
#
#                     originaldc                     destinationdc
# 0  São Paulo - Vila Leopoldina               São Paulo - Cambuci
# 1  São Paulo - Vila Leopoldina                  São Paulo - Lapa
# 2  São Paulo - Vila Leopoldina  [INATIVO]Campinas - Jd. do Trevo
# 3                      Cajamar             São Paulo - Guarulhos
# 4  São Paulo - Vila Leopoldina          [INATIVO] Santos - Saboó

# %% [markdown]
# ### Table Name: weather (Weather by time for Brazilian Locations)

# %%
sql = """select * from weather limit 5;"""
Task_df = run_query(sql)
Task_df.head()
# Out:
#    estacao        data  hora  precipitacao  tempbulboseco  tempbulboumido  \
# 0    82900  2018-01-01     0           NaN           26.6            23.1
# 1    82900  2018-01-01  1200           0.0           29.7            23.3
# 2    82900  2018-01-01  1800           NaN           30.9            25.4
# 3    82900  2018-01-02     0           NaN           27.2            24.9
# 4    82900  2018-01-02  1200           0.0           29.5            24.7
#
#    tempmaxima  tempminima  umidaderelativa  pressaoatmestacao  ...  \
# 0        32.4         NaN             73.0             1012.3  ...
# 1         NaN        23.2             57.0             1012.0  ...
# 2         NaN         NaN             63.0             1010.5  ...
# 3        31.9         NaN             82.0             1011.3  ...
# 4         NaN        21.8             67.0             1011.7  ...
#
#    direcaovento  velocidadevento  insolacao  nebulosidade  evaporacaopiche  \
# 0           5.0              0.8        9.5           5.0              6.4
# 1          14.0              2.5        NaN           4.0              NaN
# 2           9.0              2.5        NaN           8.0              NaN
# 3          14.0              3.0        9.5           4.0              4.1
# 4           9.0              1.0        NaN           7.0              NaN
#
#    tempcompmedia  umidaderelativamedia  velocidadedoventomedia  field19  \
# 0          27.94                  71.0                2.666667     None
# 1            NaN                   NaN                     NaN     None
# 2            NaN                   NaN                     NaN     None
# 3          27.44                  70.0                1.500000     None
# 4            NaN                   NaN                     NaN     None
#
#                    city
# 0  RECIFE  CURADO  - PE
# 1  RECIFE  CURADO  - PE
# 2  RECIFE  CURADO  - PE
# 3  RECIFE  CURADO  - PE
# 4  RECIFE  CURADO  - PE
#
# [5 rows x 21 columns]
